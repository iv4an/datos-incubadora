// %%
@file:DependsOn("com.github.doyaaaaaken:kotlin-csv-jvm:0.7.3")
import com.github.doyaaaaaken.kotlincsv.client.*

// %%
val csvData = java.io.File("Incubadora-datos (1).csv")
val datos: List<Map<String, String>> = CsvReader().readAllWithHeader(csvData)
println(datos)
// Out:
// [{Fecha =6/20/2022, Hora=00:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =6/20/2022, Hora=1:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =6/20/2022, Hora=2:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =6/20/2022, Hora=3:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =, Hora=, TEMPERATURA=, HUMEDAD=, =}, {Fecha =6/20/2022, Hora=4:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=4:20 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=4:40 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=5:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=5:20 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=5:40 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=6:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=6:20 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=6:40 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=7:00 HRS, TEMPERATURA=37°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=7:20 HRS, TEMPERATURA=35°, HUMEDAD=56%, =}, {Fecha =6/20/2022, Hora=7:40 HRS, TEMPERATURA=35°, HUMEDAD=56%, =}, {Fecha =6/20/2022, Hora=8:00 HRS, TEMPERATURA=35°, HUMEDAD=56%, =}, {Fecha =6/20/2022, Hora=8:20 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=8:40 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=9:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=9:20 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=9:40 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=10:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=10:20 HRS, TEMPERATURA=38��, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=10:40 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=11:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=11:20 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=11:40 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=12:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=12:20 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=12:40 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=13:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=13:20 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {Fecha =6/20/2022, Hora=13:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=14:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=14:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=14:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=15:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=15:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=15:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=16:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=16:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=16:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=17:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=17:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=17:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=18:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=18:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=18:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=19:00 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=19:20 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=19:40 HRS, TEMPERATURA=36°, HUMEDAD=65%, =}, {Fecha =6/20/2022, Hora=20:00 HRS, TEMPERATURA=38°, HUMEDAD=60%, =}, {F ...
